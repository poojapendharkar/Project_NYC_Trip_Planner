# %%
# Cleaning the dataset "Hiking Trails_Raw"

# %%
pip install geopy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import all the required libraries
import pandas as pd
from pandas_profiling import ProfileReport
import numpy as np
import sys
from sklearn.neighbors import DistanceMetric
from math import radians
from math import dist
from geopy import distance
from geopy.geocoders import Nominatim
from geopy import geocoders
from geopy.exc import GeocoderTimedOut

# %%
# Read the CSV file "directory-of-hiking-trails.csv" into the dataframe "df_hikingtrails"
df_hikingtrails = pd.read_csv("C:\\Users\\HP\\Downloads\\Hiking Trails_Raw.csv")
df_hikingtrails
# Out:
#    Prop_ID                                          Name  \
# 0     B057                       Salt Marsh Nature Trail
# 1     B073                                     Lullwater
# 2     B073                                       Midwood
# 3     B073                                     Peninsula
# 4     B073                                     Waterfall
# 5     Q001                             Alley Pond Trails
# 6     Q015                                    Blue Trail
# 7     Q015                                  Orange Trail
# 8     Q015                                  Yellow Trail
# 9     Q021                          South Preserve Trail
# 10    R013     Greenbelt Blue Trail (Southern Trailhead)
# 11    R013                 Greenbelt Nature Center Trail
# 12    R013                           Greenbelt Red Trail
# 13    R013              Greenbelt White Trail (Southern)
# 14    R013  Greenbelt Yellow Trail (Southwest Trailhead)
# ...

# %%
# Profile the dataframe "df_hikingtrails"
profile = ProfileReport(df_hikingtrails, title="Profile Report for Hiking Trails")
profile.to_file("Hiking Trails Profile Report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Drop unrelevant columns from the dataframe "df_hikingtrails"
df_hikingtrails.drop(["Prop_ID", "Park_Name", "Length", "Difficulty", "Accessible", "Limited_Access", "lat", "lon"], axis=1, inplace=True)
df_hikingtrails
# Out:
#                                             Name  \
# 0                        Salt Marsh Nature Trail
# 1                                      Lullwater
# 2                                        Midwood
# 3                                      Peninsula
# 4                                      Waterfall
# 5                              Alley Pond Trails
# 6                                     Blue Trail
# 7                                   Orange Trail
# 8                                   Yellow Trail
# 9                           South Preserve Trail
# 10     Greenbelt Blue Trail (Southern Trailhead)
# 11                 Greenbelt Nature Center Trail
# 12                           Greenbelt Red Trail
# 13              Greenbelt White Trail (Southern)
# 14  Greenbelt Yellow Trail (Southwest Trailhead)
# 15   William T. Davis Wildlife Refuge Pink Trail
# 16                  Willowbrook Park White Trail
# 17              Gretta Moulton Trail/Green Trail
# ...

# %%
# Handle missing values and null values
for c in df_hikingtrails.columns:
    missing_val = df_hikingtrails[c].isnull().sum()
    if missing_val>0:
        print("{} has {} missing value(s)".format(c, missing_val))
    else:
        print("{} has NO missing value!".format(c))
# Out:
# Name has NO missing value!
# Location has NO missing value!
# Other_Details has 4 missing value(s)

# %%
# Check the number of rows and columns before dropping rows
df_hikingtrails.shape
# Out:
# (34, 3)

# %%
# Deal with the missing values in the column "TEL"
df_hikingtrails["Other_Details"] = df_hikingtrails["Other_Details"].fillna("Not Available")
df_hikingtrails
# Out:
#                                             Name  \
# 0                        Salt Marsh Nature Trail
# 1                                      Lullwater
# 2                                        Midwood
# 3                                      Peninsula
# 4                                      Waterfall
# 5                              Alley Pond Trails
# 6                                     Blue Trail
# 7                                   Orange Trail
# 8                                   Yellow Trail
# 9                           South Preserve Trail
# 10     Greenbelt Blue Trail (Southern Trailhead)
# 11                 Greenbelt Nature Center Trail
# 12                           Greenbelt Red Trail
# 13              Greenbelt White Trail (Southern)
# 14  Greenbelt Yellow Trail (Southwest Trailhead)
# 15   William T. Davis Wildlife Refuge Pink Trail
# 16                  Willowbrook Park White Trail
# 17              Gretta Moulton Trail/Green Trail
# ...

# %%
# Handle missing values and null values
for c in df_hikingtrails.columns:
    missing_val = df_hikingtrails[c].isnull().sum()
    if missing_val>0:
        print("{} has {} missing value(s)".format(c, missing_val))
    else:
        print("{} has NO missing value!".format(c))
# Out:
# Name has NO missing value!
# Location has NO missing value!
# Other_Details has NO missing value!

# %%
# Check the number of rows and columns before dropping rows
df_hikingtrails.shape
# Out:
# (34, 3)

# %%
# Check the datatypes of the columns
datatypes = df_hikingtrails.dtypes
datatypes
# Out:
# Name             object
# Location         object
# Other_Details    object
# dtype: object

# %%
# Add four new columns "CATEGORY", "ZIPCODE", "PHONE NO.", and "URL"
df_hikingtrails["CATEGORY"] = "Hiking Trail"
df_hikingtrails["ZIPCODE"] = ""
df_hikingtrails["PHONE NO."] = "Not Available"
df_hikingtrails["URL"] = "Not Available"
df_hikingtrails
# Out:
#                                             Name  \
# 0                        Salt Marsh Nature Trail
# 1                                      Lullwater
# 2                                        Midwood
# 3                                      Peninsula
# 4                                      Waterfall
# 5                              Alley Pond Trails
# 6                                     Blue Trail
# 7                                   Orange Trail
# 8                                   Yellow Trail
# 9                           South Preserve Trail
# 10     Greenbelt Blue Trail (Southern Trailhead)
# 11                 Greenbelt Nature Center Trail
# 12                           Greenbelt Red Trail
# 13              Greenbelt White Trail (Southern)
# 14  Greenbelt Yellow Trail (Southwest Trailhead)
# 15   William T. Davis Wildlife Refuge Pink Trail
# 16                  Willowbrook Park White Trail
# 17              Gretta Moulton Trail/Green Trail
# ...

# %%
# Rename the columns
df_hikingtrails.rename(columns={"Name":"NAME", "Location":"ADDRESS", "Other_Details":"ADDITIONAL DETAILS"}, inplace=True)
df_hikingtrails
# Out:
#                                             NAME  \
# 0                        Salt Marsh Nature Trail
# 1                                      Lullwater
# 2                                        Midwood
# 3                                      Peninsula
# 4                                      Waterfall
# 5                              Alley Pond Trails
# 6                                     Blue Trail
# 7                                   Orange Trail
# 8                                   Yellow Trail
# 9                           South Preserve Trail
# 10     Greenbelt Blue Trail (Southern Trailhead)
# 11                 Greenbelt Nature Center Trail
# 12                           Greenbelt Red Trail
# 13              Greenbelt White Trail (Southern)
# 14  Greenbelt Yellow Trail (Southwest Trailhead)
# 15   William T. Davis Wildlife Refuge Pink Trail
# 16                  Willowbrook Park White Trail
# 17              Gretta Moulton Trail/Green Trail
# ...

# %%
# Rearrange the columns
df_hikingtrails = df_hikingtrails[["CATEGORY", "NAME", "ADDRESS", "ZIPCODE", "PHONE NO.", "URL", "ADDITIONAL DETAILS"]]
df_hikingtrails
# Out:
#         CATEGORY                                          NAME  \
# 0   Hiking Trail                       Salt Marsh Nature Trail
# 1   Hiking Trail                                     Lullwater
# 2   Hiking Trail                                       Midwood
# 3   Hiking Trail                                     Peninsula
# 4   Hiking Trail                                     Waterfall
# 5   Hiking Trail                             Alley Pond Trails
# 6   Hiking Trail                                    Blue Trail
# 7   Hiking Trail                                  Orange Trail
# 8   Hiking Trail                                  Yellow Trail
# 9   Hiking Trail                          South Preserve Trail
# 10  Hiking Trail     Greenbelt Blue Trail (Southern Trailhead)
# 11  Hiking Trail                 Greenbelt Nature Center Trail
# 12  Hiking Trail                           Greenbelt Red Trail
# 13  Hiking Trail              Greenbelt White Trail (Southern)
# ...

# %%
# Export the dataframe "df_hikingtrails" to a CSV file
df_hikingtrails.to_csv("C:\\Users\\HP\\Downloads\\Hiking Trails.csv", index=False)
